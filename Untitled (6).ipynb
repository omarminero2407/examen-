# %%
print('Ingrese los coeficientes de la ecuacion cuadratica ax² + bx + c = 0')
dis = -1
while dis < 0:
    a = float(input('Ingrese {a}'))
    b = float(input('Ingrese {b}'))
    c = float(input('Ingrese {c}'))
    dis = (b*b)-(4*a*c)
    if dis < 0:
        print('Error, el discriminante tiene que ser positivo')

print('La ecuación a resolver es {a}x² + {b}x + {c} = 0'.format(a=a, b=b, c=c))

x1 = (-b +(b**2 - 4*a*c)**.5)/(2*a)
x2 = (-b -(b**2 - 4*a*c)**.5)/(2*a)
print('x1 = {x1}'.format(x1=x1))
print('x2 = {x2}'.format(x2=x2))
# Out:
# Ingrese los coeficientes de la ecuacion cuadratica ax² + bx + c = 0
# Ingrese {a}1
# Ingrese {b}5
# Ingrese {c}6
# La ecuación a resolver es 1.0x² + 5.0x + 6.0 = 0
# x1 = -2.0
# x2 = -3.0

# %%
def funcion(x):
    return (x**2) + (3*x) + 3

x = float(input('Ingrese el punto en el que desea evaluar la funcion f(x) = x² + 3x + 3: '))
y = funcion(x)

print('f(x) = {y}'.format(y=y))

contador = -4
miLista=[]
while contador < 11:
    valor = funcion(contador)
    if valor > 30: 
        break
    miLista.append(valor)
    contador = contador + 1
    
print(miLista)
# Out:
# Ingrese el punto en el que desea evaluar la funcion f(x) = x² + 3x + 3: 4
# f(x) = 31.0
# [7, 3, 1, 1, 3, 7, 13, 21]
